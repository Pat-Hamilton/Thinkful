# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

df = pd.read_sql_query('select * from useducation',con=engine)

engine.dispose()

# %%
# 1.
df.info()
df.isnull().sum()*100/df.isnull().count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1280 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1319 non-null float64
# GRADES_KG_G                     1360 non-null float64
# ...

# %%
# 2.
df2 = df.copy()
df3 = df.copy()
columns = list(df.columns)

remove = {'PRIMARY_KEY', 'STATE', 'YEAR', 'AVG_READING_8_SCORE', 'AVG_READING_4_SCORE', 'AVG_MATH_8_SCORE', 'AVG_MATH_4_SCORE'}
columns = [e for e in columns if e not in remove]

for col in columns:
    df3.loc[:, col].fillna(df3.loc[:, col].mean(), inplace=True)



# Below is just for my own learning purposes    

# Are these two equivalent? Why use .loc[:]?
# for col in columns:
#     df2[col].fillna(df2[col].mean(), inplace=True)

# df2.describe()
# df3.describe()
# print(df2 == df3)

# for column_name in columns:
#     try:
#         df2[column_name] == df3[column_name]
#     except:
#         print(df2[column_name] != df3[column_name])

# %%
# 3.
df4 = df.copy()
years = df['YEAR'].unique()

for column in columns:
    for year in years:
        df4.loc[df4['YEAR'] == year][column].fillna(
            df4[df4['YEAR'] == year][column].mean(), inplace=True)
        
# Is df4.loc[df4['YEAR'] == year][column] the same as df4.loc[df4['YEAR'] == year, column]

# %%
# 4.
df5 = df.copy()

for col in columns:
    df5.loc[:, col].interpolate(inplace=True)

# %%
# 5.
# I tried doing what the sample solution did, but in a much more messy manner.
# Not sure if pd.concat's been in the curriculum already, but if so I forgot about it

# Note to ask about later, is the join argument of pd.concat in the lesson later? 
# I'm want to learn that regardless, just want to see if I'll be doing that on my own or not.


for col in columns:
    print("{} Summary".format(col))
    print(pd.concat([df[col], df3[col],
                     df4[col], df5[col]], axis=1).describe())
# Out:
# ENROLL Summary
#              ENROLL        ENROLL        ENROLL        ENROLL
# count  1.229000e+03  1.492000e+03  1.229000e+03  1.456000e+03
# mean   9.159308e+05  9.159308e+05  9.159308e+05  1.005984e+06
# std    1.065280e+06  9.667725e+05  1.065280e+06  1.009158e+06
# min    4.386600e+04  4.386600e+04  4.386600e+04  4.386600e+04
# 25%    2.583140e+05  3.150940e+05  2.583140e+05  2.973995e+05
# 50%    6.483130e+05  8.204140e+05  6.483130e+05  7.540845e+05
# 75%    1.014528e+06  9.211780e+05  1.014528e+06  1.595024e+06
# max    6.307022e+06  6.307022e+06  6.307022e+06  6.307022e+06
# TOTAL_REVENUE Summary
#        TOTAL_REVENUE  TOTAL_REVENUE  TOTAL_REVENUE  TOTAL_REVENUE
# count   1.280000e+03   1.492000e+03   1.280000e+03   1.492000e+03
# mean    9.092082e+06   9.092082e+06   9.092082e+06   1.111164e+07
# std     1.174519e+07   1.087818e+07   1.174519e+07   1.200155e+07
# min     4.656500e+05   4.656500e+05   4.656500e+05   4.656500e+05
# ...

# %%
fig = plt.figure(figsize=(20,100))

for i, col in enumerate(fill_list):
    df = pd.concat([df[col], df3[col],
                     df4[col], df5[col]], axis=1)
    
    plt.subplot(len(fill_list), 4, i+1)
    plt.bar(["original", "overall", "year-by-year", "interpolation"], df.median())
    plt.xticks(rotation='vertical')
    plt.title("Mod of {}".format(col))
    
plt.tight_layout()
plt.show()
