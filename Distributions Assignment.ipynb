# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

binom = np.random.binomial(20, .7, 100)
plt.axvline(binom.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(binom.mean() + binom.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(binom.mean() - binom.std(), color='b', linestyle='dashed', linewidth=2)
plt.hist(binom)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

gamma = np.random.gamma(20, 2, 100)
plt.axvline(gamma.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(gamma.mean() + gamma.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(gamma.mean() - gamma.std(), color='b', linestyle='dashed', linewidth=2)
plt.hist(gamma)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

weibull = np.random.weibull(10, 100)
plt.axvline(weibull.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(weibull.mean() + weibull.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(weibull.mean() - weibull.std(), color='b', linestyle='dashed', linewidth=2)
plt.hist(weibull)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

poisson = np.random.poisson(500, 100)
plt.axvline(poisson.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(poisson.mean() + poisson.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(poisson.mean() - poisson.std(), color='b', linestyle='dashed', linewidth=2)
plt.hist(poisson)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

negbinom = np.random.negative_binomial(1, .3, 100)
plt.axvline(negbinom.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(negbinom.mean() + negbinom.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(negbinom.mean() - negbinom.std(), color='b', linestyle='dashed', linewidth=2)
plt.hist(negbinom)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

lognorm = np.random.lognormal(1, .3, 100)
plt.axvline(lognorm.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(lognorm.mean() + lognorm.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(lognorm.mean() - lognorm.std(), color='b', linestyle='dashed', linewidth=2)
plt.hist(lognorm)
plt.show()

# %%
print('In general, the mean and sd will be a poor measure of central tendency and variance when the distribution is not symmetrical')
# Out:
# In general, the mean and sd will be a poor measure of central tendency and variance when the distribution is not symmetrical

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

norm1 = np.random.normal(10,1, 100)
norm2 = np.random.normal(25,3, 100)
var = norm1+norm2

plt.hist(norm3)
plt.axvline(var.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(var.mean() + var.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(var.mean() - var.std(), color='b', linestyle='dashed', linewidth=2)
plt.show()
print('Results should vary due to randomness, but they will probably be scewed due to the difference in means and variance')
# Out:
# Results should vary due to randomness, but they will probably be scewed due to the difference in means and variance
